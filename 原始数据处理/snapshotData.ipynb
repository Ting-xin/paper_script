# %%
import glob
import json
import re
import hashlib
import json

def gen_md5_id(item):
    md5_machine = hashlib.md5()
    md5_machine.update(item.encode('utf-8'))
    return md5_machine.hexdigest()

src_dir = r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\province_geojson'

files = glob.glob(src_dir + '\\*', recursive=True)

result = []   # 每个 item 增加一个生命周期，每碰见一个新的item，就加入result，并且将该生命期作为启示，如果该年没有这个item，则表示生命期结束
pre_year = {}
now_year = {}
len_all = 0
for file in files:
  year = re.compile('\d+\.json').findall(file)[0].replace('.json', '')
  year = int(year)
  with open(file, encoding='utf-8') as f:
    data = json.load(f).get('features')
    len_all += len(data)
    now_year = {}
    for i in data:
      properties = i.get('properties')
      pcode = properties['PCODE']
      if 'PROV_CH' in properties:
        name = properties['PROV_CH']
      else:
        name = properties['PROV_CN']
      geometry = i.get('geometry')
      id = gen_md5_id(str(pcode) + str(name) + str(geometry))

      temp = {}
      temp['name'] = name
      temp['code'] = pcode
      temp['geometry'] = geometry
      now_year[id] = temp
    
    temp = {}

    for i in pre_year:
      if i not in now_year:
        pre_year[i]['eYear'] = year
        result.append(pre_year[i])
      else:
        temp[i] = pre_year[i]
    pre_year = temp
    
    for i in now_year:
      if i not in pre_year:
        now_year[i]['sYear'] = year
        pre_year[i] = now_year[i]


for i in pre_year.values():
  if 'eYear' not in i :
    i['eYear'] = 2015
  result.append(i)

with open(r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\province.json', 'w', encoding='utf-8') as f:
  json.dump(result, f, ensure_ascii=False,indent = 4)

# %%
def gen_md5_id(item):
    md5_machine = hashlib.md5()
    md5_machine.update(item.encode('utf-8'))
    return md5_machine.hexdigest()
    
src_dir = r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\city_geojson'

files = glob.glob(src_dir + '\\*', recursive=True)

result = []   # 每个 item 增加一个生命周期，每碰见一个新的item，就加入result，并且将该生命期作为启示，如果该年没有这个item，则表示生命期结束
pre_year = {}
now_year = {}
len_all = 0
for file in files:
  year = re.compile('\d+\.json').findall(file)[0].replace('.json', '')
  year = int(year)
  with open(file, encoding='utf-8') as f:
    data = json.load(f).get('features')
    len_all += len(data)
    now_year = {}
    for i in data:
      properties = i.get('properties')
      dcode = properties['DCODE']
      if 'PROV_CH' in properties:
        prov_name = properties['PROV_CH']
      else:
        prov_name = properties['PROV_CN']
      if 'CITY_CH' in properties:
        name = properties['CITY_CH']
      else:
        name = properties['CITY_CN']
      if prov_name != name:
        name = prov_name + name
      geometry = i.get('geometry')
      id = gen_md5_id(str(dcode) + str(name) + str(geometry))

      temp = {}
      temp['name'] = name
      temp['code'] = dcode
      temp['geometry'] = geometry
      now_year[id] = temp
    
    temp = {}

    for i in pre_year:
      if i not in now_year:
        pre_year[i]['eYear'] = year
        result.append(pre_year[i])
      else:
        temp[i] = pre_year[i]
    pre_year = temp
    
    for i in now_year:
      if i not in pre_year:
        now_year[i]['sYear'] = year
        pre_year[i] = now_year[i]


for i in pre_year.values():
  if 'eYear' not in i :
    i['eYear'] = 2015
  result.append(i)

with open(r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\city.json', 'w', encoding='utf-8') as f:
  json.dump(result, f, ensure_ascii=False,indent = 4)

# %%
src_dir = r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\county_geojson'

files = glob.glob(src_dir + '\\*', recursive=True)

result = []   # 每个 item 增加一个生命周期，每碰见一个新的item，就加入result，并且将该生命期作为启示，如果该年没有这个item，则表示生命期结束
pre_year = {}
now_year = {}
len_all = 0
for file in files:
  year = re.compile('\d+\.json').findall(file)[0].replace('.json', '')
  year = int(year)
  with open(file, encoding='utf-8') as f:
    data = json.load(f).get('features')
    len_all += len(data)
    now_year = {}
    for i in data:
      properties = i.get('properties')
      dcode = properties['CODE' + str(year)]
      if 'PROV_CH' in properties:
        prov_name = properties['PROV_CH']
      else:
        prov_name = properties['PROV_CN']
      if 'CITY_CH' in properties:
        city_name = properties['CITY_CH']
      else:
        city_name = properties['CITY_CN']
      if prov_name != city_name:
        city_name = prov_name + city_name
      if 'COUNTY_CH' in properties:
        name = properties['COUNTY_CH']
      else:
        name = properties['COUNTY_CN']
      if city_name != name:
        name = city_name + name
      geometry = i.get('geometry')
      id = gen_md5_id(str(dcode) + str(name) + str(geometry))

      temp = {}
      temp['name'] = name
      temp['code'] = dcode
      temp['geometry'] = geometry
      now_year[id] = temp
    
    temp = {}

    for i in pre_year:
      if i not in now_year:
        pre_year[i]['eYear'] = year
        result.append(pre_year[i])
      else:
        temp[i] = pre_year[i]
    pre_year = temp
    
    for i in now_year:
      if i not in pre_year:
        now_year[i]['sYear'] = year
        pre_year[i] = now_year[i]


for i in pre_year.values():
  if 'eYear' not in i :
    i['eYear'] = 2015
  result.append(i)

with open(r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\county.json', 'w', encoding='utf-8') as f:
  json.dump(result, f, ensure_ascii=False,indent = 4)

# %%
import glob
import json
import re
import hashlib
import json

# %%
def gen_md5_id(item):
    md5_machine = hashlib.md5()
    md5_machine.update(item.encode('utf-8'))
    return md5_machine.hexdigest()


src_dir = r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\county_geojson'

files = glob.glob(src_dir + '\\*', recursive=True)

result = []   # 每个 item 增加一个生命周期，每碰见一个新的item，就加入result，并且将该生命期作为启示，如果该年没有这个item，则表示生命期结束
pre_year = {}
now_year = {}
len_all = 0
for file in files:
  year = re.compile('\d+\.json').findall(file)[0].replace('.json', '')
  year = int(year)
  with open(file, encoding='utf-8') as f:
    data = json.load(f).get('features')
    len_all += len(data)
    now_year = {}
    for i in data:
      properties = i.get('properties')
      geometry = i.get('geometry')
      name = properties['地名']
      code = properties['code']
      id = gen_md5_id(str(code) + str(name) + str(geometry))

      temp = {}
      temp['name'] = name
      temp['code'] = code
      temp['geometry'] = geometry
      now_year[id] = temp

    temp = {}

    for i in pre_year:
      if i not in now_year:
        pre_year[i]['eYear'] = year
        result.append(pre_year[i])
      else:
        temp[i] = pre_year[i]
    pre_year = temp

    for i in now_year:
      if i not in pre_year:
        now_year[i]['sYear'] = year
        pre_year[i] = now_year[i]


for i in pre_year.values():
  if 'eYear' not in i:
    i['eYear'] = 2023
  result.append(i)

print('最终个数：', len(result))

with open(r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\county.json', 'w', encoding='utf-8') as f:
  json.dump(result, f, ensure_ascii=False, indent=4)
# Out:
# 最终个数： 3447

# %%
src_dir = r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\province_geojson'

files = glob.glob(src_dir + '\\*', recursive=True)

result = []   # 每个 item 增加一个生命周期，每碰见一个新的item，就加入result，并且将该生命期作为启示，如果该年没有这个item，则表示生命期结束
pre_year = {}
now_year = {}
len_all = 0
for file in files:
  year = re.compile('\d+\.json').findall(file)[0].replace('.json', '')
  year = int(year)
  with open(file, encoding='utf-8') as f:
    data = json.load(f).get('features')
    len_all += len(data)
    now_year = {}
    for i in data:
      properties = i.get('properties')
      geometry = i.get('geometry')
      name = properties['省']
      code = properties['省级码']
      id = gen_md5_id(str(code) + str(name) + str(geometry))

      temp = {}
      temp['name'] = name
      temp['code'] = code
      temp['geometry'] = geometry
      now_year[id] = temp

    temp = {}

    for i in pre_year:
      if i not in now_year:
        pre_year[i]['eYear'] = year
        result.append(pre_year[i])
      else:
        temp[i] = pre_year[i]
    pre_year = temp

    for i in now_year:
      if i not in pre_year:
        now_year[i]['sYear'] = year
        pre_year[i] = now_year[i]


for i in pre_year.values():
  if 'eYear' not in i:
    i['eYear'] = 2023
  result.append(i)

print('最终个数：', len(result))

with open(r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\province.json', 'w', encoding='utf-8') as f:
  json.dump(result, f, ensure_ascii=False, indent=4)
# Out:
# 最终个数： 34

# %%
src_dir = r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\city_geojson'

files = glob.glob(src_dir + '\\*', recursive=True)

result = []   # 每个 item 增加一个生命周期，每碰见一个新的item，就加入result，并且将该生命期作为启示，如果该年没有这个item，则表示生命期结束
pre_year = {}
now_year = {}
len_all = 0
for file in files:
  year = re.compile('\d+\.json').findall(file)[0].replace('.json', '')
  year = int(year)
  with open(file, encoding='utf-8') as f:
    data = json.load(f).get('features')
    len_all += len(data)
    now_year = {}
    for i in data:
      properties = i.get('properties')
      geometry = i.get('geometry')
      name = properties['地名']
      code = properties['code']
      id = gen_md5_id(str(code) + str(name) + str(geometry))

      temp = {}
      temp['name'] = name
      temp['code'] = code
      temp['geometry'] = geometry
      now_year[id] = temp

    temp = {}

    for i in pre_year:
      if i not in now_year:
        pre_year[i]['eYear'] = year
        result.append(pre_year[i])
      else:
        temp[i] = pre_year[i]
    pre_year = temp

    for i in now_year:
      if i not in pre_year:
        now_year[i]['sYear'] = year
        pre_year[i] = now_year[i]


for i in pre_year.values():
  if 'eYear' not in i:
    i['eYear'] = 2023
  result.append(i)

print('最终个数：', len(result))

with open(r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\city.json', 'w', encoding='utf-8') as f:
  json.dump(result, f, ensure_ascii=False, indent=4)
# Out:
# 最终个数： 415

# %%
tempFile = r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\county_geojson\2022.json'

# %%
src_dir = r'E:\paper\data\原始数据\历年行政区划数据\2015-2022原始数据\county_geojson'

files = glob.glob(src_dir + '\\*', recursive=True)

len_all = 0
for file in files:
  year = re.compile('\d+\.json').findall(file)[0].replace('.json', '')
  year = int(year)
  with open(file, encoding='utf-8') as f:
    data = json.load(f).get('features')
    len_all = len_all + len(data)

# with open(r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\county.json', 'w', encoding='utf-8') as f:
#   json.dump(result, f, ensure_ascii=False, indent=4)

# %%
len_all
# Out:
# 22874

# %%
with open(r'E:\paper\data\原始数据\历年行政区划数据\1949-2014伯克利数据\county.json', 'r', encoding='utf-8') as f:
  data = json.load(f)
  print(len(data))
# Out:
# 25750
